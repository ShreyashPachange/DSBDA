# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/sample_data/HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222     18.7  396.90    NaN  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273     21.0  391.99    NaN  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
x = df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]
y=df['MEDV']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')  # or 'median', 'most_frequent'
x_train_imputed = imputer.fit_transform(x_train)

model = LinearRegression()
model.fit(x_train_imputed, y_train)
# Out:
# LinearRegression()

# %%
train_data = pd.concat([x_train, y_train], axis=1)
train_data = train_data.dropna()

# Split back
x_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test_clean = x_test.dropna()
y_pred = model.predict(x_test_clean)

# %%
imputer = SimpleImputer(strategy='mean')
x_train_imputed = imputer.fit_transform(x_train)

# Train model
model = LinearRegression()
model.fit(x_train_imputed, y_train)

# Apply SAME imputer to x_test
x_test_imputed = imputer.transform(x_test)

# Now predict
y_pred = model.predict(x_test_imputed)

# %%
# ... (previous code) ...

# Impute missing values in x_test using the same imputer fitted on x_train
x_test_imputed = imputer.transform(x_test)

# Now predict using the imputed x_test
y_pred = model.predict(x_test_imputed)

# %%
y_pred
# Out:
# array([28.70508098, 36.01189742, 15.36658463, 25.35058703, 18.43223334,
#        23.16275218, 18.47971822, 16.00646137, 21.94593209, 20.3204164 ,
#        25.20055364, 19.23910974, -5.98266132, 22.31498804, 18.6246063 ,
#        25.70207519, 21.08634668,  6.13558655, 40.99325507, 17.15978974,
#        25.39541061, 30.1091336 , 12.11015018, 23.2610956 , 16.69013885,
#        14.57603969, 21.53372114, 14.02183372, 23.19843856, 18.8854191 ,
#        21.20654733, 25.00114468, 25.9547399 , 15.2251866 , 16.57126009,
#        16.07670934, 31.11729005, 20.026749  , 24.58657145, 23.6779109 ,
#        14.31885189, 31.49368146, 43.30652453, 17.82022069, 26.63846424,
#        15.89409397, 14.04105921, 26.76083798, 19.88779157, 28.92919976,
#        21.06156456, 33.29179787, 16.68355886, 25.85887346, 38.86652027,
#        22.21682542, 18.36414544, 32.77705724, 25.22896404, 14.29566553,
#        23.6767694 , 31.60937588, 30.60532982, 15.64534231, 20.89606788,
#        17.31526948, 20.06143353, 25.98685289, 30.6773616 , 10.5393187 ,
#        21.25384381, 26.44620214, 10.81725316, 12.92935244, 23.9354841 ,
#         6.82201383, 20.92899455, 42.00304196, 18.95037733,  9.7306812 ,
#        20.98618004, 13.21787887, 21.60227101,  8.97353057, 22.35670359,
#        31.56228902, 18.95681883, 25.40046042, 29.0350352 , 20.4823538 ,
#        25.07494887,  5.23189141, 20.02720532, 15.53313255,  7.81050636,
#        20.50107163, 22.58481597, -0.53226399, 12.7536749 , 15.64328715,
#        22.60325599, 24.62568005, 10.58800035, 18.93027521, 22.70535774,
#        12.20175155, 17.83789723, 25.62817241, 20.91495266, 24.24815125,
#         7.75079413, 20.58454566, 22.00273764, 26.73210297, 31.83586724,
#        13.62914833, 35.3478067 , 12.76535886, 20.2585721 , 28.03073586,
#        15.24853344, 25.16263388,  3.24702918, 22.66755212, 25.9620605 ,
#        22.56625209, 25.20722287])

# %%
model.score(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# 0.7846490837751618

# %%
# Impute missing values in x_test using the same imputer fitted on x_train
x_test_imputed = imputer.transform(x_test)

# Now calculate the score using the imputed x_test
score = model.score(x_test_imputed, y_test)

print(score) # Print the score
# Out:
# 0.6648779612191507

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 23.467639151424176

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(4.8443409408736064)
